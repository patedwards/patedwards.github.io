# %% [markdown]
# From https://mobility.here.com/learn/travel-apis/top-5-bus-and-transit-apis, found Google Maps transit API

# %%
API_KEY = "AIzaSyDgLIiCRFAR2PvGe56py6FaNOwyXwshcj0"

url = f"https://maps.googleapis.com/maps/api/directions/json?origin=Toronto&destination=Montreal&key={API_KEY}&mode=transit"

# %%
import requests

# %%
r = requests.get(url)

# %%
r.json()['geocoded_waypoints']
# Out:
# [{'geocoder_status': 'OK',
#   'place_id': 'ChIJpTvG15DL1IkRd8S0KlBVNTI',
#   'types': ['locality', 'political']},
#  {'geocoder_status': 'OK',
#   'place_id': 'ChIJDbdkHFQayUwR7-8fITgxTmU',
#   'types': ['locality', 'political']}]

# %%
r.json().keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
len(r.json()['routes'])
# Out:
# 1

# %%
r.json()['routes'][0]['legs'][0].keys()
# Out:
# dict_keys(['arrival_time', 'departure_time', 'distance', 'duration', 'end_address', 'end_location', 'start_address', 'start_location', 'steps', 'traffic_speed_entry', 'via_waypoint'])

# %%
r.json()['routes'][0]['legs'][0]['steps']
# Out:
# 2

# %%
r.json()['routes'][0]['legs'][0]['steps'][0]['polyline']
# Out:
# {'points': 'ymkiG|_ocNdBaA]qCIo@S_BEUE]QeAScBCSCQEo@C_@Ee@Eo@?EI}BIeCMaCMeCMcAIy@U_CG}@G_AGc@a@{C]mCE_@Ga@AMCSWgBS_BeB{ME]E[wCkU?EM{@M}@CMKm@O{@?CI]G]WgAiA_FGSo@qCgCmKK_@K_@Om@Oc@Wo@cGcNsA}C_AuBqAiDaCoFGOSc@ACSa@Wg@GMMWUe@_@s@a@q@GGg@w@e@m@KKo@s@o@m@e@a@QOm@a@AA]SYSEAy@c@s@[w@Yu@Sw@Q_AQg@EWEaBKy@GOAoCQw@GmBM}@Eu@Gw@Gk@Gq@Im@Ik@Ik@Ke@Ik@Mm@Os@Sm@QcA_@c@Oc@Se@Q_@SqAo@aAe@aAi@}@i@u@c@]SqA{@o@c@]Yo@g@MI][e@_@gAeAGGq@q@[]AAo@u@s@y@qA_BiA{AOUq@cAw@kAo@gAq@kAs@sAc@_Ai@mAUg@_@_Ac@eAk@{Ai@yAg@_B_@iAe@_BgIyXa@wA{D}MkLca@Wy@{Lkb@gIeYY}@Ok@a@wAQi@Ok@uA{EiDqLwBwH{@uCy@{Ck@uBc@eBGQg@uBe@yBe@wBWsAWwAWuAUqASqASqAi@qD_F{\\oB}MEa@k@{Dk@}DOcAE[Ko@Io@U_B_@mCcFc^[}BU}AUwAWyAUuAYyA[uAKg@Oo@Oi@Mi@_@wASo@Ka@Us@K_@c@qAe@sAc@mAe@mAg@mAm@sAw@aBu@}A}@_BKOo@gAWc@Yc@q@_Ao@}@q@{@o@w@o@u@s@u@u@y@s@q@w@s@u@q@w@o@y@m@{@m@w@k@yA{@{J}FgSmL_Ai@aDkBcGkDiWeOu@_@s@_@c@SwBmAu@e@aIuE{@k@m@a@y@i@}FiD_Ai@aCwA_@SaDkBcCwAaMkHuBmA_e@gXOK_B_AmBmAq@c@k@a@{AkA{AoA_B}AeAgAg@k@e@i@c@i@e@k@c@k@a@i@e@o@c@o@c@q@a@q@a@o@]o@_AcB{AqC{GcMuEu
# ...

# %%
# !pip install polyline

# %%
import polyline
polyline.decode(r.json()['routes'][0]['legs'][0]['steps'][0]['polyline']['points'])
# Out:
# [(43.64525, -79.38063),
#  (43.64474, -79.3803),
#  (43.64489, -79.37957),
#  (43.64494, -79.37933),
#  (43.64504, -79.37885),
#  (43.64507, -79.37874),
#  (43.6451, -79.37859),
#  (43.64519, -79.37824),
#  (43.64529, -79.37774),
#  (43.64531, -79.37764),
#  (43.64533, -79.37755),
#  (43.64536, -79.37731),
#  (43.64538, -79.37715),
#  (43.64541, -79.37696),
#  (43.64544, -79.37672),
#  (43.64544, -79.37669),
#  (43.64549, -79.37606),
#  (43.64554, -79.37539),
#  (43.64561, -79.37474),
#  (43.64568, -79.37407),
#  (43.64575, -79.37373),
#  (43.6458, -79.37344),
#  (43.64591, -79.3728),
#  (43.64595, -79.37249),
#  (43.64599, -79.37217),
#  (43.64603, -79.37199),
#  (43.6462, -79.37121),
#  (43.64635, -79.3705),
#  (43.64638, -79.37034),
#  (43.64642, -79.37017),
#  (43.64643, -79.3701),
#  (43.64645, -79.37),
#  (43.64657, -79.36948),
#  (43.64667, -79.369),
#  (43.64718, -79.36662),
#  (43.64721, -79.36647),
#  (43.64724, -79.36633),
#  (43.648, -79.36275),
#  (43.648, -79.36272),
# ...

# %%
import matplotlib.pyplot as plt
import osmnx as ox
from IPython.display import Image
# %matplotlib inline
ox.config(log_console=True, use_cache=True)
ox.__version__
# Out:
# /Users/patrick/.virtualenvs/jupyter/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# '0.16.1'

# %%
# configure the inline image display
img_folder = 'images'
extension = 'png'
size = 240

# specify that we're retrieving building footprint geometries
tags = {'building': True}

# %%
gdf = ox.geometries_from_place('Seattle, Washington, USA', tags)
# Out:
# /Users/patrick/.virtualenvs/jupyter/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
len(gdf)
# Out:
# /Users/patrick/.virtualenvs/jupyter/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 205729

# %%
# !mkdir data

# %%
gdf = ox.geometries_from_place('Vancouver, British Columbia, Canada', tags)
# Out:
# /Users/patrick/.virtualenvs/jupyter/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
len(gdf)
# Out:
# /Users/patrick/.virtualenvs/jupyter/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 133087

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_proj = ox.project_gdf(gdf)
fp = f'./{img_folder}/piedmont_bldgs.{extension}'
fig, ax = ox.plot_footprints(gdf_proj, filepath=fp, dpi=400, save=True, show=False, close=True)
Image(fp, height=size, width=size)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-590aa0e06b23> in <module>
# ----> 1 gdf = ox.geometries_from_place('Piedmont, California, USA', tags)
#       2 gdf_proj = ox.project_gdf(gdf)
#       3 fp = f'./{img_folder}/piedmont_bldgs.{extension}'
#       4 fig, ax = ox.plot_footprints(gdf_proj, filepath=fp, dpi=400, save=True, show=False, close=True)
#       5 Image(fp, height=size, width=size)
#
# ~/.virtualenvs/jupyter/lib/python3.7/site-packages/osmnx/geometries.py in geometries_from_place(query, tags, which_result, buffer_dist)
#     213
#     214     # create GeoDataFrame using this polygon(s) geometry
# --> 215     gdf = geometries_from_polygon(polygon, tags)
#     216
#     217     return gdf
#
# ~/.virtualenvs/jupyter/lib/python3.7/site-packages/osmnx/geometries.py in geometries_from_polygon(polygon, tags)
#     260
# ...
